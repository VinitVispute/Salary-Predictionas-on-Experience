# %% [markdown]
# # Predict salary Base on year's experience

# %%
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv('salaryData.csv')
x = pd.DataFrame(dataset.iloc[:,:-1])
y = pd.DataFrame(dataset.iloc[:,-1])

# %%
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
dataset.head(2)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205

# %%
dataset.head(5)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %% [markdown]
# #this is another way for loading the values of experience into x

# %%
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %% [markdown]
# #years of experience

# %%
#salary
y
# Out:
#     Salary
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# 5    56642
# 6    60150
# 7    54445
# 8    64445
# 9    57189
# 10   63218
# 11   55794
# 12   56957
# 13   57081
# 14   61111
# 15   67938
# 16   66029
# 17   83088
# 18   81363
# 19   93940
# 20   91738
# 21   98273
# 22  101302
# 23  113812
# 24  109431
# 25  105582
# 26  116969
# 27  112635
# 28  122391
# 29  121872

# %%
dataset
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 1/3, random_state = 1)

# %%
xTrain
# Out:
#     YearsExperience
# 23              8.2
# 4               2.2
# 2               1.5
# 25              9.0
# 6               3.0
# 18              5.9
# 13              4.1
# 7               3.2
# 27              9.6
# 1               1.3
# 16              5.1
# 0               1.1
# 15              4.9
# 29             10.5
# 28             10.3
# 9               3.7
# 8               3.2
# 12              4.0
# 11              4.0
# 5               2.9

# %%
 yTrain
# Out:
#     Salary
# 23  113812
# 4    39891
# 2    37731
# 25  105582
# 6    60150
# 18   81363
# 13   57081
# 7    54445
# 27  112635
# 1    46205
# 16   66029
# 0    39343
# 15   67938
# 29  121872
# 28  122391
# 9    57189
# 8    64445
# 12   56957
# 11   55794
# 5    56642

# %%
xTest
# Out:
#     YearsExperience
# 17              5.3
# 21              7.1
# 10              3.9
# 19              6.0
# 14              4.5
# 20              6.8
# 26              9.5
# 3               2.0
# 24              8.7
# 22              7.9

# %%
yTest
# Out:
#     Salary
# 17   83088
# 21   98273
# 10   63218
# 19   93940
# 14   61111
# 20   91738
# 26  116969
# 3    43525
# 24  109431
# 22  101302

# %% [markdown]
# # Linear Regression

# %%
linearRegressor = LinearRegression()
linearRegressor.fit(xTrain, yTrain)
# Out:
# LinearRegression()

# %%
print(linearRegressor.intercept_)
print(linearRegressor.coef_)
# Out:
# [26137.2400142]
# [[9158.13919873]]

# %%
# Predicting the test set results
yPrediction = linearRegressor.predict(xTest)

# %%
xTest
# Out:
#     YearsExperience
# 17              5.3
# 21              7.1
# 10              3.9
# 19              6.0
# 14              4.5
# 20              6.8
# 26              9.5
# 3               2.0
# 24              8.7
# 22              7.9

# %%
yPrediction
# Out:
# array([[ 74675.37776747],
#        [ 91160.02832519],
#        [ 61853.98288925],
#        [ 81086.07520659],
#        [ 67348.86640849],
#        [ 88412.58656557],
#        [113139.56240215],
#        [ 44453.51841166],
#        [105813.05104316],
#        [ 98486.53968418]])

# %%
yTest
# Out:
#     Salary
# 17   83088
# 21   98273
# 10   63218
# 19   93940
# 14   61111
# 20   91738
# 26  116969
# 3    43525
# 24  109431
# 22  101302

# %%
dataset.to_numpy()
# Out:
# array([[1.10000e+00, 3.93430e+04],
#        [1.30000e+00, 4.62050e+04],
#        [1.50000e+00, 3.77310e+04],
#        [2.00000e+00, 4.35250e+04],
#        [2.20000e+00, 3.98910e+04],
#        [2.90000e+00, 5.66420e+04],
#        [3.00000e+00, 6.01500e+04],
#        [3.20000e+00, 5.44450e+04],
#        [3.20000e+00, 6.44450e+04],
#        [3.70000e+00, 5.71890e+04],
#        [3.90000e+00, 6.32180e+04],
#        [4.00000e+00, 5.57940e+04],
#        [4.00000e+00, 5.69570e+04],
#        [4.10000e+00, 5.70810e+04],
#        [4.50000e+00, 6.11110e+04],
#        [4.90000e+00, 6.79380e+04],
#        [5.10000e+00, 6.60290e+04],
#        [5.30000e+00, 8.30880e+04],
#        [5.90000e+00, 8.13630e+04],
#        [6.00000e+00, 9.39400e+04],
#        [6.80000e+00, 9.17380e+04],
#        [7.10000e+00, 9.82730e+04],
#        [7.90000e+00, 1.01302e+05],
#        [8.20000e+00, 1.13812e+05],
#        [8.70000e+00, 1.09431e+05],
#        [9.00000e+00, 1.05582e+05],
#        [9.50000e+00, 1.16969e+05],
# ...

# %%
# Visualising the test set results
plot.scatter(xTest, yTest, color = 'red')
plot.plot(xTest, linearRegressor.predict(xTest), color = 'blue')
plot.title('Salary vs Experience (Test set)')
plot.xlabel('Years of Experience')
plot.ylabel('Salary')
plot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ANC\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# C:\Users\ANC\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\Users\ANC\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), None)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8712/3512463768.py in <module>
#       1 # Visualising the test set results
#       2 plot.scatter(xTest, yTest, color = 'red')
# ...

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html

# %%
from sklearn.metrics import r2_score
r2_score(yTest, yPrediction, sample_weight=None, multioutput='uniform_average')
# Out:
# 0.9240850478446321

# %%
xTest.values.dtype
# Out:
# dtype('float64')

# %%
xTest.values.flatten()
# Out:
# array([5.3, 7.1, 3.9, 6. , 4.5, 6.8, 9.5, 2. , 8.7, 7.9])

# %%
 d = {'Experience':xTest,'ActualSalary':yTest,'PredictedSalary':yPrediction}

# %%
d
# Out:
# {'Experience':     YearsExperience
#  17              5.3
#  21              7.1
#  10              3.9
#  19              6.0
#  14              4.5
#  20              6.8
#  26              9.5
#  3               2.0
#  24              8.7
#  22              7.9,
#  'ActualSalary':     Salary
#  17   83088
#  21   98273
#  10   63218
#  19   93940
#  14   61111
#  20   91738
#  26  116969
#  3    43525
#  24  109431
#  22  101302,
#  'PredictedSalary': array([[ 74675.37776747],
#         [ 91160.02832519],
#         [ 61853.98288925],
#         [ 81086.07520659],
#         [ 67348.86640849],
#         [ 88412.58656557],
#         [113139.56240215],
#         [ 44453.51841166],
#         [105813.05104316],
#         [ 98486.53968418]])}

# %% [markdown]
# we can also use trainig data for predictions

# %%
# Visualising the training set results
plot.scatter(xTrain, yTrain, color = 'red')
plot.plot(xTrain, linearRegressor.predict(xTrain), color = 'blue')
plot.title('Salary vs Experience (Training set)')
plot.xlabel('Years of Experience')
plot.ylabel('Salary')
plot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ANC\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# C:\Users\ANC\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\Users\ANC\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), None)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8712/639602586.py in <module>
#       1 # Visualising the training set results
#       2 plot.scatter(xTrain, yTrain, color = 'red')
# ...

# %% [markdown]
# # Statistics side of the model

# %%
import statsmodels.api as sm
# Out:
# C:\Users\ANC\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\ANC\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
X2=sm.add_constant(xTrain)
est = sm.OLS(yTrain,X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.959
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     420.8
# Date:                Fri, 15 Apr 2022   Prob (F-statistic):           6.21e-14
# Time:                        12:36:23   Log-Likelihood:                -200.98
# No. Observations:                  20   AIC:                             406.0
# Df Residuals:                      18   BIC:                             408.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            2.614e+04   2548.831     10.255      0.000    2.08e+04    3.15e+04
# ...
